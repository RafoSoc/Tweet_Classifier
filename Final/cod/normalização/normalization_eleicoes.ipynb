# %%
# Biblioteca para ler os datasets e transformações
import pandas as pd
from remove_normalizer import ajustandoDados
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rafae\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rafae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\rafae\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rafae\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Importando dataset
dataset = pd.read_csv('C:/Users/rafae/OneDrive/Documents/GitHub/HCAI/Final/dados/raw_data/hastag_eleicao3.csv', 
                        parse_dates=['created_at'], dtype={'id_str':str})
display(dataset.head())
# Out:
#                  created_at               id_str  \
# 0 2022-10-24 23:59:59+00:00  1584696235050823680
# 1 2022-10-24 23:59:57+00:00  1584696227777478656
# 2 2022-10-24 23:59:56+00:00  1584696222102614016
# 3 2022-10-24 23:59:55+00:00  1584696219720634368
# 4 2022-10-24 23:59:53+00:00  1584696211252318208
#
#                                            full_text  \
# 0  Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 1  RT @choquei: 🚨GRAVE: Médicos em hospital de Na...
# 2  RT @UOLNoticias: IPEC PRESIDENCIAL: 2º turno -...
# 3  RT @portalR7: Bolsonaro diz que Brasil é o 7º ...
# 4  RT @choquei: 🚨AGORA: Jason Momoa, nosso Aquama...
#
#                  user.location  \
# 0                       Narnia
# 1                          NaN
# 2                          NaN
# 3            Fortaleza, Brasil
# 4  Rio Grande do Norte, Brasil
#
#                                    entities.hashtags  \
# 0  [{'text': 'Noticias', 'indices': [15, 24]}, {'...
# 1  [{'text': 'Eleições2022', 'indices': [126, 139]}]
# 2  [{'text': 'Eleições2022', 'indices': [93, 106]...
# 3  [{'text': 'R7', 'indices': [102, 105]}, {'text...
# 4   [{'text': 'Eleiçoes2022', 'indices': [91, 104]}]
#
#                           retweeted_status.full_text
# 0                                                NaN
# 1  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 2  IPEC PRESIDENCIAL: 2º turno - Lula tem 54%, Bo...
# 3  Bolsonaro diz que Brasil é o 7º país mais digi...
# 4  🚨AGORA: Jason Momoa, nosso Aquaman, declarou a...

# %%
# Substitui os valores NAN da coluna retweeted_status.full_text pelos valores correspondentes da linha da coluna full_text
dataset['all_full_text'] = dataset['retweeted_status.full_text'].fillna(dataset['full_text'])
display(dataset)
# Out:
#                    created_at               id_str  \
# 0   2022-10-24 23:59:59+00:00  1584696235050823680
# 1   2022-10-24 23:59:57+00:00  1584696227777478656
# 2   2022-10-24 23:59:56+00:00  1584696222102614016
# 3   2022-10-24 23:59:55+00:00  1584696219720634368
# 4   2022-10-24 23:59:53+00:00  1584696211252318208
# ..                        ...                  ...
# 995 2022-10-24 23:31:28+00:00  1584689058026229760
# 996 2022-10-24 23:31:25+00:00  1584689047322398723
# 997 2022-10-24 23:31:23+00:00  1584689038342385664
# 998 2022-10-24 23:31:23+00:00  1584689036333002753
# 999 2022-10-24 23:31:20+00:00  1584689026052681728
#
#                                              full_text  \
# 0    Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 1    RT @choquei: 🚨GRAVE: Médicos em hospital de Na...
# 2    RT @UOLNoticias: IPEC PRESIDENCIAL: 2º turno -...
# 3    RT @portalR7: Bolsonaro diz que Brasil é o 7º ...
# 4    RT @choquei: 🚨AGORA: Jason Momoa, nosso Aquama...
# ..                                                 ...
# 995  #Eleições2022 | Cid Gomes grava vídeo de apoio...
# 996  RT @choquei: 🚨GRAVE: Médicos em hospital de Na...
# 997  RT @InstitutoVerit1: O Veritá avaliou também a...
# 998  RT @choquei: 🚨GRAVE: Médicos em hospital de Na...
# 999  RT @JHFonseca: ***URGENTE: MINISTRO DAS COMUNI...
#
#                    user.location  \
# 0                         Narnia
# 1                            NaN
# 2                            NaN
# 3              Fortaleza, Brasil
# 4    Rio Grande do Norte, Brasil
# ..                           ...
# 995                    Fortaleza
# 996             São Luís, Brasil
# 997                          NaN
# 998                          NaN
# 999                          NaN
#
#                                      entities.hashtags  \
# 0    [{'text': 'Noticias', 'indices': [15, 24]}, {'...
# 1    [{'text': 'Eleições2022', 'indices': [126, 139]}]
# 2    [{'text': 'Eleições2022', 'indices': [93, 106]...
# 3    [{'text': 'R7', 'indices': [102, 105]}, {'text...
# 4     [{'text': 'Eleiçoes2022', 'indices': [91, 104]}]
# ..                                                 ...
# 995     [{'text': 'Eleições2022', 'indices': [0, 13]}]
# 996  [{'text': 'Eleições2022', 'indices': [126, 139]}]
# 997                                                 []
# 998  [{'text': 'Eleições2022', 'indices': [126, 139]}]
# 999                                                 []
#
#                             retweeted_status.full_text  \
# 0                                                  NaN
# 1    🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 2    IPEC PRESIDENCIAL: 2º turno - Lula tem 54%, Bo...
# 3    Bolsonaro diz que Brasil é o 7º país mais digi...
# 4    🚨AGORA: Jason Momoa, nosso Aquaman, declarou a...
# ..                                                 ...
# 995                                                NaN
# 996  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 997  O Veritá avaliou também a intenção de voto cap...
# 998  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 999  ***URGENTE: MINISTRO DAS COMUNICAÇÕES DENUNCIA...
#
#                                          all_full_text
# 0    Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 1    🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 2    IPEC PRESIDENCIAL: 2º turno - Lula tem 54%, Bo...
# 3    Bolsonaro diz que Brasil é o 7º país mais digi...
# 4    🚨AGORA: Jason Momoa, nosso Aquaman, declarou a...
# ..                                                 ...
# 995  #Eleições2022 | Cid Gomes grava vídeo de apoio...
# 996  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 997  O Veritá avaliou também a intenção de voto cap...
# 998  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 999  ***URGENTE: MINISTRO DAS COMUNICAÇÕES DENUNCIA...
#
# [1000 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# created_at                    datetime64[ns, UTC]
# id_str                                     object
# full_text                                  object
# user.location                              object
# entities.hashtags                          object
# retweeted_status.full_text                 object
# all_full_text                              object
# dtype: object

# %%
dataset['retweeted_status.full_text'] = dataset['retweeted_status.full_text'].astype(str)
dataset['id_str'] = dataset['id_str'].astype(str)
dataset['full_text'] = dataset['full_text'].astype(str)
dataset['created_at'] = dataset['created_at'].astype(str)
print(dataset.dtypes)
print('')
display(dataset)
# Out:
# created_at                    object
# id_str                        object
# full_text                     object
# user.location                 object
# entities.hashtags             object
# retweeted_status.full_text    object
# all_full_text                 object
# dtype: object
#                     created_at               id_str  \
# 0    2022-10-24 23:59:59+00:00  1584696235050823680
# 1    2022-10-24 23:59:57+00:00  1584696227777478656
# 2    2022-10-24 23:59:56+00:00  1584696222102614016
# 3    2022-10-24 23:59:55+00:00  1584696219720634368
# 4    2022-10-24 23:59:53+00:00  1584696211252318208
# ..                         ...                  ...
# 995  2022-10-24 23:31:28+00:00  1584689058026229760
# 996  2022-10-24 23:31:25+00:00  1584689047322398723
# 997  2022-10-24 23:31:23+00:00  1584689038342385664
# 998  2022-10-24 23:31:23+00:00  1584689036333002753
# 999  2022-10-24 23:31:20+00:00  1584689026052681728
#
#                                              full_text  \
# 0    Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 1    RT @choquei: 🚨GRAVE: Médicos em hospital de Na...
# 2    RT @UOLNoticias: IPEC PRESIDENCIAL: 2º turno -...
# 3    RT @portalR7: Bolsonaro diz que Brasil é o 7º ...
# 4    RT @choquei: 🚨AGORA: Jason Momoa, nosso Aquama...
# ..                                                 ...
# 995  #Eleições2022 | Cid Gomes grava vídeo de apoio...
# 996  RT @choquei: 🚨GRAVE: Médicos em hospital de Na...
# 997  RT @InstitutoVerit1: O Veritá avaliou também a...
# 998  RT @choquei: 🚨GRAVE: Médicos em hospital de Na...
# 999  RT @JHFonseca: ***URGENTE: MINISTRO DAS COMUNI...
#
#                    user.location  \
# 0                         Narnia
# 1                            NaN
# 2                            NaN
# 3              Fortaleza, Brasil
# 4    Rio Grande do Norte, Brasil
# ..                           ...
# 995                    Fortaleza
# 996             São Luís, Brasil
# 997                          NaN
# 998                          NaN
# 999                          NaN
#
#                                      entities.hashtags  \
# 0    [{'text': 'Noticias', 'indices': [15, 24]}, {'...
# 1    [{'text': 'Eleições2022', 'indices': [126, 139]}]
# 2    [{'text': 'Eleições2022', 'indices': [93, 106]...
# 3    [{'text': 'R7', 'indices': [102, 105]}, {'text...
# 4     [{'text': 'Eleiçoes2022', 'indices': [91, 104]}]
# ..                                                 ...
# 995     [{'text': 'Eleições2022', 'indices': [0, 13]}]
# 996  [{'text': 'Eleições2022', 'indices': [126, 139]}]
# 997                                                 []
# 998  [{'text': 'Eleições2022', 'indices': [126, 139]}]
# 999                                                 []
#
#                             retweeted_status.full_text  \
# 0                                                  nan
# 1    🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 2    IPEC PRESIDENCIAL: 2º turno - Lula tem 54%, Bo...
# 3    Bolsonaro diz que Brasil é o 7º país mais digi...
# 4    🚨AGORA: Jason Momoa, nosso Aquaman, declarou a...
# ..                                                 ...
# 995                                                nan
# 996  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 997  O Veritá avaliou também a intenção de voto cap...
# 998  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 999  ***URGENTE: MINISTRO DAS COMUNICAÇÕES DENUNCIA...
#
#                                          all_full_text
# 0    Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 1    🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 2    IPEC PRESIDENCIAL: 2º turno - Lula tem 54%, Bo...
# 3    Bolsonaro diz que Brasil é o 7º país mais digi...
# 4    🚨AGORA: Jason Momoa, nosso Aquaman, declarou a...
# ..                                                 ...
# 995  #Eleições2022 | Cid Gomes grava vídeo de apoio...
# 996  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 997  O Veritá avaliou também a intenção de voto cap...
# 998  🚨GRAVE: Médicos em hospital de Natal-RN constr...
# 999  ***URGENTE: MINISTRO DAS COMUNICAÇÕES DENUNCIA...
#
# [1000 rows x 7 columns]

# %%
display(dataset['full_text'][1])
# Out:
# 'RT @choquei: 🚨GRAVE: Médicos em hospital de Natal-RN constrangem e coagem paciente em trabalho de parto a votar em Bolsonaro. #Eleições2022…'

# %%
mask = dataset['full_text'].str.contains(r'''RT @[\w_]+:''')
tweets = dataset[~mask]
display(tweets)
# Out:
#                     created_at               id_str  \
# 0    2022-10-24 23:59:59+00:00  1584696235050823680
# 12   2022-10-24 23:59:37+00:00  1584696144512196609
# 33   2022-10-24 23:59:02+00:00  1584695998701391873
# 35   2022-10-24 23:58:58+00:00  1584695981614206981
# 43   2022-10-24 23:58:49+00:00  1584695943039160320
# ..                         ...                  ...
# 961  2022-10-24 23:32:10+00:00  1584689234296070145
# 964  2022-10-24 23:32:05+00:00  1584689213659717632
# 985  2022-10-24 23:31:40+00:00  1584689110614413312
# 989  2022-10-24 23:31:36+00:00  1584689093510037505
# 995  2022-10-24 23:31:28+00:00  1584689058026229760
#
#                                              full_text  \
# 0    Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 12   @ThiagoResiste ATENÇÃO: Moraes acaba de respon...
# 33   Enquanto eu puder fazer campanha para manter a...
# 35   Bolsonaro, Jefferson e a luta armada: "povo ar...
# 43   Estou enojada com este contexto político. Só t...
# ..                                                 ...
# 961  O moço só faltou desenhar na lousa o que realm...
# 964  Paulo Dantas (MDB) havia sido afastado por 180...
# 985  Em 14 dias, mais de 154 mil inserções de rádio...
# 989  Lula @lula em ato pela Defesa da Democracia e ...
# 995  #Eleições2022 | Cid Gomes grava vídeo de apoio...
#
#               user.location  \
# 0                    Narnia
# 12                      NaN
# 33                      NaN
# 35   Belo Horizonte, Brasil
# 43     Porto Alegre, Brasil
# ..                      ...
# 961         Porto, Portugal
# 964             Teresina-PI
# 985          Rio de Janeiro
# 989             Stalingrado
# 995               Fortaleza
#
#                                      entities.hashtags  \
# 0    [{'text': 'Noticias', 'indices': [15, 24]}, {'...
# 12   [{'text': 'Eleições2022', 'indices': [282, 295]}]
# 33   [{'text': 'Eleicoes2022', 'indices': [86, 99]}...
# 35   [{'text': 'RobertoJeffersonEBolsonaro', 'indic...
# 43   [{'text': 'Eleicoes2022', 'indices': [223, 236...
# ..                                                 ...
# 961  [{'text': 'NaoMexaNoMeuSalário', 'indices': [2...
# 964  [{'text': 'stj', 'indices': [170, 174]}, {'tex...
# 985   [{'text': 'Eleicoes2022', 'indices': [97, 110]}]
# 989  [{'text': 'Eleicao2022', 'indices': [56, 68]},...
# 995     [{'text': 'Eleições2022', 'indices': [0, 13]}]
#
#     retweeted_status.full_text  \
# 0                          nan
# 12                         nan
# 33                         nan
# 35                         nan
# 43                         nan
# ..                         ...
# 961                        nan
# 964                        nan
# 985                        nan
# 989                        nan
# 995                        nan
#
#                                          all_full_text
# 0    Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 12   @ThiagoResiste ATENÇÃO: Moraes acaba de respon...
# 33   Enquanto eu puder fazer campanha para manter a...
# 35   Bolsonaro, Jefferson e a luta armada: "povo ar...
# 43   Estou enojada com este contexto político. Só t...
# ..                                                 ...
# 961  O moço só faltou desenhar na lousa o que realm...
# 964  Paulo Dantas (MDB) havia sido afastado por 180...
# 985  Em 14 dias, mais de 154 mil inserções de rádio...
# 989  Lula @lula em ato pela Defesa da Democracia e ...
# 995  #Eleições2022 | Cid Gomes grava vídeo de apoio...
#
# [77 rows x 7 columns]

# %%
ajustandoDados.remove_user_hash(tweets,'full_text')
# Out:
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r"@[A-Za-z0-9_]+", 'xuserx', regex=True)
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r"#[A-Za-z0-9_]+", 'xhashtagx', regex=True)

# %%
ajustandoDados.remove_misc1(tweets,'full_text')
display(tweets.head())
# Out:
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.strip()
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.lower()
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r'http\S+', 'xurlx', regex=True)
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r'\n+', ' ',regex=True)
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
#                    created_at               id_str  \
# 0   2022-10-24 23:59:59+00:00  1584696235050823680
# 12  2022-10-24 23:59:37+00:00  1584696144512196609
# 33  2022-10-24 23:59:02+00:00  1584695998701391873
# 35  2022-10-24 23:58:58+00:00  1584695981614206981
# 43  2022-10-24 23:58:49+00:00  1584695943039160320
#
#                                             full_text           user.location  \
# 0   genteeeee! \r xhashtagx xhashtagx xhashtagx xurlx                  Narnia
# 12  xuserx atencao: moraes acaba de responder a ca...                     NaN
# 33  enquanto eu puder fazer campanha para manter a...                     NaN
# 35  bolsonaro, jefferson e a luta armada: "povo ar...  Belo Horizonte, Brasil
# 43  estou enojada com este contexto politico. so t...    Porto Alegre, Brasil
#
#                                     entities.hashtags  \
# 0   [{'text': 'Noticias', 'indices': [15, 24]}, {'...
# 12  [{'text': 'Eleições2022', 'indices': [282, 295]}]
# 33  [{'text': 'Eleicoes2022', 'indices': [86, 99]}...
# 35  [{'text': 'RobertoJeffersonEBolsonaro', 'indic...
# 43  [{'text': 'Eleicoes2022', 'indices': [223, 236...
#
#    retweeted_status.full_text  \
# 0                         nan
# 12                        nan
# 33                        nan
# 35                        nan
# 43                        nan
#
#                                         all_full_text
# 0   Genteeeee! 🤨🤔😱\r\n#Noticias #Brasil #Eleicoes2...
# 12  @ThiagoResiste ATENÇÃO: Moraes acaba de respon...
# 33  Enquanto eu puder fazer campanha para manter a...
# 35  Bolsonaro, Jefferson e a luta armada: "povo ar...
# 43  Estou enojada com este contexto político. Só t...

# %%
tweets2 = tweets[['created_at', 'id_str', 'full_text', 'user.location', 'entities.hashtags']]
display(tweets2.head())
print('')
print(tweets2.dtypes)
# Out:
#                    created_at               id_str  \
# 0   2022-10-24 23:59:59+00:00  1584696235050823680
# 12  2022-10-24 23:59:37+00:00  1584696144512196609
# 33  2022-10-24 23:59:02+00:00  1584695998701391873
# 35  2022-10-24 23:58:58+00:00  1584695981614206981
# 43  2022-10-24 23:58:49+00:00  1584695943039160320
#
#                                             full_text           user.location  \
# 0   genteeeee! \r xhashtagx xhashtagx xhashtagx xurlx                  Narnia
# 12  xuserx atencao: moraes acaba de responder a ca...                     NaN
# 33  enquanto eu puder fazer campanha para manter a...                     NaN
# 35  bolsonaro, jefferson e a luta armada: "povo ar...  Belo Horizonte, Brasil
# 43  estou enojada com este contexto politico. so t...    Porto Alegre, Brasil
#
#                                     entities.hashtags
# 0   [{'text': 'Noticias', 'indices': [15, 24]}, {'...
# 12  [{'text': 'Eleições2022', 'indices': [282, 295]}]
# 33  [{'text': 'Eleicoes2022', 'indices': [86, 99]}...
# 35  [{'text': 'RobertoJeffersonEBolsonaro', 'indic...
# 43  [{'text': 'Eleicoes2022', 'indices': [223, 236...
# created_at           object
# id_str               object
# full_text            object
# user.location        object
# entities.hashtags    object
# dtype: object

# %%
with pd.ExcelWriter('C:/Users/rafae/OneDrive/Documents/GitHub/HCAI/Final/dados/train_data/tweets_eleicoes.xlsx') as writer:
    tweets2.to_excel(writer, sheet_name='tweets_trat', index=False)
