# %%
# Biblioteca para ler os datasets e transformações
import pandas as pd

from remove_normalizer import ajustandoDados

# %%
# Importando dataset
dataset = pd.read_csv('C:/Users/rafae/OneDrive/Documents/GitHub/HCAI/Final/dados/raw_data/lula3.csv', 
                        parse_dates=['created_at'], dtype={'id_str':str})
display(dataset.head())
# Out:
#                  created_at               id_str  \
# 0 2022-10-26 20:26:05+00:00  1585367180165943296
# 1 2022-10-26 20:26:05+00:00  1585367180144967680
# 2 2022-10-26 20:26:05+00:00  1585367180090445824
# 3 2022-10-26 20:26:04+00:00  1585367179226419201
# 4 2022-10-26 20:26:04+00:00  1585367178941206528
#
#                                            full_text  \
# 0  RT @Carlinh66685715: Assisti Moro e Deltan, no...
# 1  RT @SRivoltril: "Ainnnn sinto falta de mulher ...
# 2  @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 3  RT @bala_luca: @jairmearrependi VOTO EM LULA P...
# 4  RT @GilDoVigor: Eu vim da periferia, pobre, mã...
#
#                user.location entities.hashtags  \
# 0                       Roma                []
# 1  Fazenda Rio Grande Paraná                []
# 2                        NaN                []
# 3        São Vicente, Brasil                []
# 4              Belém, Brasil                []
#
#                           retweeted_status.full_text
# 0  Assisti Moro e Deltan, no Flow. Reforço: LULA ...
# 1  "Ainnnn sinto falta de mulher na campanha do L...
# 2                                                NaN
# 3  @jairmearrependi VOTO EM LULA PORQUE O VÉI DA ...
# 4  Eu vim da periferia, pobre, mãe solo e meu ace...

# %%
# Substitui os valores NAN da coluna retweeted_status.full_text pelos valores correspondentes da linha da coluna full_text
dataset['all_full_text'] = dataset['retweeted_status.full_text'].fillna(dataset['full_text'])
display(dataset)
# Out:
#                    created_at               id_str  \
# 0   2022-10-26 20:26:05+00:00  1585367180165943296
# 1   2022-10-26 20:26:05+00:00  1585367180144967680
# 2   2022-10-26 20:26:05+00:00  1585367180090445824
# 3   2022-10-26 20:26:04+00:00  1585367179226419201
# 4   2022-10-26 20:26:04+00:00  1585367178941206528
# ..                        ...                  ...
# 995 2022-10-26 20:24:58+00:00  1585366902503018496
# 996 2022-10-26 20:24:58+00:00  1585366902423322626
# 997 2022-10-26 20:24:58+00:00  1585366901927997440
# 998 2022-10-26 20:24:58+00:00  1585366901844512769
# 999 2022-10-26 20:24:58+00:00  1585366901810921472
#
#                                              full_text  \
# 0    RT @Carlinh66685715: Assisti Moro e Deltan, no...
# 1    RT @SRivoltril: "Ainnnn sinto falta de mulher ...
# 2    @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 3    RT @bala_luca: @jairmearrependi VOTO EM LULA P...
# 4    RT @GilDoVigor: Eu vim da periferia, pobre, mã...
# ..                                                 ...
# 995  O carn era bolsonarista? Ta fazendo campanha p...
# 996  RT @ClaudeLuca_: Lula regulou a mídia através ...
# 997  PAULO VIEIRA E LULA\r\n\r\nHADDAD NO FLOW\r\n\...
# 998  RT @J_LIVRES: Vamos às ruas, no corpo a corpo,...
# 999  A grande família sempre foi a sitcom mais peti...
#
#                  user.location  \
# 0                         Roma
# 1    Fazenda Rio Grande Paraná
# 2                          NaN
# 3          São Vicente, Brasil
# 4                Belém, Brasil
# ..                         ...
# 995     Rio de Janeiro, Brasil
# 996                  Salto- SP
# 997            Москва, Rússia
# 998                        NaN
# 999                        NaN
#
#                                      entities.hashtags  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 995                                                 []
# 996  [{'text': 'RadiolaoDoPT', 'indices': [120, 133]}]
# 997                                                 []
# 998   [{'text': 'Eleicao2022', 'indices': [109, 121]}]
# 999                                                 []
#
#                             retweeted_status.full_text  \
# 0    Assisti Moro e Deltan, no Flow. Reforço: LULA ...
# 1    "Ainnnn sinto falta de mulher na campanha do L...
# 2                                                  NaN
# 3    @jairmearrependi VOTO EM LULA PORQUE O VÉI DA ...
# 4    Eu vim da periferia, pobre, mãe solo e meu ace...
# ..                                                 ...
# 995                                                NaN
# 996  Lula regulou a mídia através do TSE durante a ...
# 997                                                NaN
# 998  Vamos às ruas, no corpo a corpo, sem medo, com...
# 999                                                NaN
#
#                                          all_full_text
# 0    Assisti Moro e Deltan, no Flow. Reforço: LULA ...
# 1    "Ainnnn sinto falta de mulher na campanha do L...
# 2    @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 3    @jairmearrependi VOTO EM LULA PORQUE O VÉI DA ...
# 4    Eu vim da periferia, pobre, mãe solo e meu ace...
# ..                                                 ...
# 995  O carn era bolsonarista? Ta fazendo campanha p...
# 996  Lula regulou a mídia através do TSE durante a ...
# 997  PAULO VIEIRA E LULA\r\n\r\nHADDAD NO FLOW\r\n\...
# 998  Vamos às ruas, no corpo a corpo, sem medo, com...
# 999  A grande família sempre foi a sitcom mais peti...
#
# [1000 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# created_at                    datetime64[ns, UTC]
# id_str                                     object
# full_text                                  object
# user.location                              object
# entities.hashtags                          object
# retweeted_status.full_text                 object
# all_full_text                              object
# dtype: object

# %%
dataset['retweeted_status.full_text'] = dataset['retweeted_status.full_text'].astype(str)
dataset['id_str'] = dataset['id_str'].astype(str)
dataset['full_text'] = dataset['full_text'].astype(str)
dataset['created_at'] = dataset['created_at'].astype(str)
print(dataset.dtypes)
print('')
display(dataset)
# Out:
# created_at                    object
# id_str                        object
# full_text                     object
# user.location                 object
# entities.hashtags             object
# retweeted_status.full_text    object
# all_full_text                 object
# dtype: object
#                     created_at               id_str  \
# 0    2022-10-26 20:26:05+00:00  1585367180165943296
# 1    2022-10-26 20:26:05+00:00  1585367180144967680
# 2    2022-10-26 20:26:05+00:00  1585367180090445824
# 3    2022-10-26 20:26:04+00:00  1585367179226419201
# 4    2022-10-26 20:26:04+00:00  1585367178941206528
# ..                         ...                  ...
# 995  2022-10-26 20:24:58+00:00  1585366902503018496
# 996  2022-10-26 20:24:58+00:00  1585366902423322626
# 997  2022-10-26 20:24:58+00:00  1585366901927997440
# 998  2022-10-26 20:24:58+00:00  1585366901844512769
# 999  2022-10-26 20:24:58+00:00  1585366901810921472
#
#                                              full_text  \
# 0    RT @Carlinh66685715: Assisti Moro e Deltan, no...
# 1    RT @SRivoltril: "Ainnnn sinto falta de mulher ...
# 2    @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 3    RT @bala_luca: @jairmearrependi VOTO EM LULA P...
# 4    RT @GilDoVigor: Eu vim da periferia, pobre, mã...
# ..                                                 ...
# 995  O carn era bolsonarista? Ta fazendo campanha p...
# 996  RT @ClaudeLuca_: Lula regulou a mídia através ...
# 997  PAULO VIEIRA E LULA\r\n\r\nHADDAD NO FLOW\r\n\...
# 998  RT @J_LIVRES: Vamos às ruas, no corpo a corpo,...
# 999  A grande família sempre foi a sitcom mais peti...
#
#                  user.location  \
# 0                         Roma
# 1    Fazenda Rio Grande Paraná
# 2                          NaN
# 3          São Vicente, Brasil
# 4                Belém, Brasil
# ..                         ...
# 995     Rio de Janeiro, Brasil
# 996                  Salto- SP
# 997            Москва, Rússia
# 998                        NaN
# 999                        NaN
#
#                                      entities.hashtags  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 995                                                 []
# 996  [{'text': 'RadiolaoDoPT', 'indices': [120, 133]}]
# 997                                                 []
# 998   [{'text': 'Eleicao2022', 'indices': [109, 121]}]
# 999                                                 []
#
#                             retweeted_status.full_text  \
# 0    Assisti Moro e Deltan, no Flow. Reforço: LULA ...
# 1    "Ainnnn sinto falta de mulher na campanha do L...
# 2                                                  nan
# 3    @jairmearrependi VOTO EM LULA PORQUE O VÉI DA ...
# 4    Eu vim da periferia, pobre, mãe solo e meu ace...
# ..                                                 ...
# 995                                                nan
# 996  Lula regulou a mídia através do TSE durante a ...
# 997                                                nan
# 998  Vamos às ruas, no corpo a corpo, sem medo, com...
# 999                                                nan
#
#                                          all_full_text
# 0    Assisti Moro e Deltan, no Flow. Reforço: LULA ...
# 1    "Ainnnn sinto falta de mulher na campanha do L...
# 2    @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 3    @jairmearrependi VOTO EM LULA PORQUE O VÉI DA ...
# 4    Eu vim da periferia, pobre, mãe solo e meu ace...
# ..                                                 ...
# 995  O carn era bolsonarista? Ta fazendo campanha p...
# 996  Lula regulou a mídia através do TSE durante a ...
# 997  PAULO VIEIRA E LULA\r\n\r\nHADDAD NO FLOW\r\n\...
# 998  Vamos às ruas, no corpo a corpo, sem medo, com...
# 999  A grande família sempre foi a sitcom mais peti...
#
# [1000 rows x 7 columns]

# %%
display(dataset['full_text'][1])
# Out:
# 'RT @SRivoltril: "Ainnnn sinto falta de mulher na campanha do Lula "\r\nTá bom pra vc ou quer mais ?? https://t.co/ENpASoXvGe'

# %%
mask = dataset['full_text'].str.contains(r'''RT @[\w_]+:''')
tweets = dataset[~mask]
display(tweets)
# Out:
#                     created_at               id_str  \
# 2    2022-10-26 20:26:05+00:00  1585367180090445824
# 6    2022-10-26 20:26:04+00:00  1585367178450468864
# 12   2022-10-26 20:26:04+00:00  1585367176881803265
# 15   2022-10-26 20:26:04+00:00  1585367176076107776
# 24   2022-10-26 20:26:03+00:00  1585367174465847296
# ..                         ...                  ...
# 982  2022-10-26 20:25:00+00:00  1585366908442136576
# 989  2022-10-26 20:24:59+00:00  1585366905317359618
# 995  2022-10-26 20:24:58+00:00  1585366902503018496
# 997  2022-10-26 20:24:58+00:00  1585366901927997440
# 999  2022-10-26 20:24:58+00:00  1585366901810921472
#
#                                              full_text  \
# 2    @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 6    Imagina os milionários artistas globais lendo ...
# 12                                  @ErikakHilton LULA
# 15   E AGORA, LULA? Bolsonaro entrega relatório com...
# 24   @AndreJanonesAdv VOTO EM LULA PORQUE :\r\nÉ JA...
# ..                                                 ...
# 982  Bolsonarista no TSE? Corte diz que assessor co...
# 989  Bolsonarista que chama Lula de mentiroso é com...
# 995  O carn era bolsonarista? Ta fazendo campanha p...
# 997  PAULO VIEIRA E LULA\r\n\r\nHADDAD NO FLOW\r\n\...
# 999  A grande família sempre foi a sitcom mais peti...
#
#               user.location entities.hashtags retweeted_status.full_text  \
# 2                       NaN                []                        nan
# 6                       NaN                []                        nan
# 12           Paraná, Brasil                []                        nan
# 15           Recife, Brasil                []                        nan
# 24                      NaN                []                        nan
# ..                      ...               ...                        ...
# 982                  Brasil                []                        nan
# 989                     NaN                []                        nan
# 995  Rio de Janeiro, Brasil                []                        nan
# 997         Москва, Rússia                 []                        nan
# 999                     NaN                []                        nan
#
#                                          all_full_text
# 2    @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 6    Imagina os milionários artistas globais lendo ...
# 12                                  @ErikakHilton LULA
# 15   E AGORA, LULA? Bolsonaro entrega relatório com...
# 24   @AndreJanonesAdv VOTO EM LULA PORQUE :\r\nÉ JA...
# ..                                                 ...
# 982  Bolsonarista no TSE? Corte diz que assessor co...
# 989  Bolsonarista que chama Lula de mentiroso é com...
# 995  O carn era bolsonarista? Ta fazendo campanha p...
# 997  PAULO VIEIRA E LULA\r\n\r\nHADDAD NO FLOW\r\n\...
# 999  A grande família sempre foi a sitcom mais peti...
#
# [201 rows x 7 columns]

# %%
ajustandoDados.remove_user_hash(tweets,'full_text')
# Out:
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r"@[A-Za-z0-9_]+", 'xuserx', regex=True)
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r"#[A-Za-z0-9_]+", 'xhashtagx', regex=True)

# %%
ajustandoDados.remove_misc1(tweets,'full_text')
display(tweets.head())
# Out:
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.strip()
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.lower()
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r'http\S+', 'xurlx', regex=True)
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.replace(r'\n+', ' ',regex=True)
# c:\Users\rafae\OneDrive\Documents\GitHub\HCAI\Final\cod\normalização\remove_normalizer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column1] = data[column1].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
#                    created_at               id_str  \
# 2   2022-10-26 20:26:05+00:00  1585367180090445824
# 6   2022-10-26 20:26:04+00:00  1585367178450468864
# 12  2022-10-26 20:26:04+00:00  1585367176881803265
# 15  2022-10-26 20:26:04+00:00  1585367176076107776
# 24  2022-10-26 20:26:03+00:00  1585367174465847296
#
#                                             full_text   user.location  \
# 2   xuserx xuserx xuserx lula ja presidente do brasil             NaN
# 6   imagina os milionarios artistas globais lendo ...             NaN
# 12                                        xuserx lula  Paraná, Brasil
# 15  e agora, lula? bolsonaro entrega relatorio com...  Recife, Brasil
# 24  xuserx voto em lula porque :\r e jair em deses...             NaN
#
#    entities.hashtags retweeted_status.full_text  \
# 2                 []                        nan
# 6                 []                        nan
# 12                []                        nan
# 15                []                        nan
# 24                []                        nan
#
#                                         all_full_text
# 2   @geraldoalckmin @LulaOficial @Haddad_Fernando ...
# 6   Imagina os milionários artistas globais lendo ...
# 12                                 @ErikakHilton LULA
# 15  E AGORA, LULA? Bolsonaro entrega relatório com...
# 24  @AndreJanonesAdv VOTO EM LULA PORQUE :\r\nÉ JA...

# %%
tweets2 = tweets[['created_at', 'id_str', 'full_text', 'user.location', 'entities.hashtags']]
display(tweets2.head())
print('')
print(tweets2.dtypes)
# Out:
#                    created_at               id_str  \
# 2   2022-10-26 20:26:05+00:00  1585367180090445824
# 6   2022-10-26 20:26:04+00:00  1585367178450468864
# 12  2022-10-26 20:26:04+00:00  1585367176881803265
# 15  2022-10-26 20:26:04+00:00  1585367176076107776
# 24  2022-10-26 20:26:03+00:00  1585367174465847296
#
#                                             full_text   user.location  \
# 2   xuserx xuserx xuserx lula ja presidente do brasil             NaN
# 6   imagina os milionarios artistas globais lendo ...             NaN
# 12                                        xuserx lula  Paraná, Brasil
# 15  e agora, lula? bolsonaro entrega relatorio com...  Recife, Brasil
# 24  xuserx voto em lula porque :\r e jair em deses...             NaN
#
#    entities.hashtags
# 2                 []
# 6                 []
# 12                []
# 15                []
# 24                []
# created_at           object
# id_str               object
# full_text            object
# user.location        object
# entities.hashtags    object
# dtype: object

# %%
with pd.ExcelWriter('C:/Users/rafae/OneDrive/Documents/GitHub/HCAI/Final/dados/train_data/tweets_lula.xlsx') as writer:
    tweets2.to_excel(writer, sheet_name='tweets_trat', index=False)
